# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
deliveries = pd.read_csv('deliveries.csv') 
matches = pd.read_csv('matches.csv')

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
# id                 756 non-null int64
# season             756 non-null int64
# city               749 non-null object
# date               756 non-null object
# team1              756 non-null object
# team2              756 non-null object
# toss_winner        756 non-null object
# toss_decision      756 non-null object
# result             756 non-null object
# dl_applied         756 non-null int64
# winner             752 non-null object
# win_by_runs        756 non-null int64
# win_by_wickets     756 non-null int64
# player_of_match    752 non-null object
# venue              756 non-null object
# umpire1            754 non-null object
# umpire2            754 non-null object
# umpire3            119 non-null object
# dtypes: int64(5), object(13)
# memory usage: 106.4+ KB

# %% [raw]
# 1. Which team has won/lost maximum number of matches while chasing?

# %%
matches['result'].unique()
# Out:
# array(['normal', 'tie', 'no result'], dtype=object)

# %%
matches['toss_decision'].unique()
# Out:
# array(['field', 'bat'], dtype=object)

# %%
same_winner = matches[matches['toss_winner'] == matches['winner']]
same_winner[same_winner['toss_decision'] == 'field']
# Out:
#         id  season           city        date                        team1  \
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 5        6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6        7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 9       10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10      11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11      12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# 12      13    2017         Rajkot  2017-04-14       Rising Pune Supergiant
# 15      16    2017         Mumbai  2017-04-16                Gujarat Lions
# 21      22    2017         Indore  2017-04-20              Kings XI Punjab
# ...

# %%
diff_winner = matches[matches['toss_winner'] != matches['winner']]
diff_winner[diff_winner['toss_decision'] =='bat']
# Out:
#         id  season            city        date                        team1  \
# 7        8    2017          Indore  2017-04-10  Royal Challengers Bangalore
# 17      18    2017           Delhi  2017-04-17             Delhi Daredevils
# 33      34    2017          Rajkot  2017-04-29                Gujarat Lions
# 36      37    2017          Mumbai  2017-05-01  Royal Challengers Bangalore
# 46      47    2017       Hyderabad  2017-05-08               Mumbai Indians
# 61      62    2008           Delhi  2008-04-19             Rajasthan Royals
# 62      63    2008          Mumbai  2008-04-20               Mumbai Indians
# 63      64    2008         Kolkata  2008-04-20              Deccan Chargers
# 64      65    2008          Jaipur  2008-04-21              Kings XI Punjab
# 65      66    2008       Hyderabad  2008-04-22              Deccan Chargers
# 70      71    2008         Chennai  2008-04-26        Kolkata Knight Riders
# ...

# %%
chasing_winners = pd.concat([same_winner, diff_winner])
chasing_winners
# Out:
#         id  season        city        date                        team1  \
# 1        2    2017        Pune  2017-04-06               Mumbai Indians
# 2        3    2017      Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 5        6    2017   Hyderabad  2017-04-09                Gujarat Lions
# 6        7    2017      Mumbai  2017-04-09        Kolkata Knight Riders
# 9       10    2017      Mumbai  2017-04-12          Sunrisers Hyderabad
# 10      11    2017     Kolkata  2017-04-13              Kings XI Punjab
# 11      12    2017   Bangalore  2017-04-14  Royal Challengers Bangalore
# 12      13    2017      Rajkot  2017-04-14       Rising Pune Supergiant
# 14      15    2017       Delhi  2017-04-15             Delhi Daredevils
# 15      16    2017      Mumbai  2017-04-16                Gujarat Lions
# ...

# %%
winner_groups = matches.groupby('winner')

# %%
count_by_winner = winner_groups.aggregate(['count'])

# %%
count_by_winner
# Out:
#                                id season  city  date team1 team2 toss_winner  \
#                             count  count count count count count       count
# winner
# Chennai Super Kings           100    100    98   100   100   100         100
# Deccan Chargers                29     29    29    29    29    29          29
# Delhi Capitals                 10     10    10    10    10    10          10
# Delhi Daredevils               67     67    66    67    67    67          67
# Gujarat Lions                  13     13    13    13    13    13          13
# Kings XI Punjab                82     82    81    82    82    82          82
# Kochi Tuskers Kerala            6      6     6     6     6     6           6
# Kolkata Knight Riders          92     92    92    92    92    92          92
# Mumbai Indians                109    109   109   109   109   109         109
# Pune Warriors                  12     12    12    12    12    12          12
# ...

# %%
matches_won = count_by_winner['id']
matches_won
# Out:
#                              count
# winner
# Chennai Super Kings            100
# Deccan Chargers                 29
# Delhi Capitals                  10
# Delhi Daredevils                67
# Gujarat Lions                   13
# Kings XI Punjab                 82
# Kochi Tuskers Kerala             6
# Kolkata Knight Riders           92
# Mumbai Indians                 109
# Pune Warriors                   12
# Rajasthan Royals                75
# Rising Pune Supergiant          10
# Rising Pune Supergiants          5
# Royal Challengers Bangalore     84
# Sunrisers Hyderabad             58

# %%
max = count_by_winner['id'].max()
max[0]
# Out:
# 109

# %%
count_by_winner_max = count_by_winner['id'] == max
count_by_winner_max
# Out:
#                              count
# winner
# Chennai Super Kings          False
# Deccan Chargers              False
# Delhi Capitals               False
# Delhi Daredevils             False
# Gujarat Lions                False
# Kings XI Punjab              False
# Kochi Tuskers Kerala         False
# Kolkata Knight Riders        False
# Mumbai Indians                True
# Pune Warriors                False
# Rajasthan Royals             False
# Rising Pune Supergiant       False
# Rising Pune Supergiants      False
# Royal Challengers Bangalore  False
# Sunrisers Hyderabad          False

# %%
count_by_winner_max[count_by_winner_max['count'] == True]
# Out:
#                 count
# winner
# Mumbai Indians   True

# %%
matches[['team1', 'team2']]
team1 = matches['team1']
team2 = matches['team2']
teams = pd.concat([team1, team2])

# %%
teams
# Out:
# 0              Sunrisers Hyderabad
# 1                   Mumbai Indians
# 2                    Gujarat Lions
# 3           Rising Pune Supergiant
# 4      Royal Challengers Bangalore
# 5                    Gujarat Lions
# 6            Kolkata Knight Riders
# 7      Royal Challengers Bangalore
# 8                 Delhi Daredevils
# 9              Sunrisers Hyderabad
# 10                 Kings XI Punjab
# 11     Royal Challengers Bangalore
# 12          Rising Pune Supergiant
# 13           Kolkata Knight Riders
# 14                Delhi Daredevils
# 15                   Gujarat Lions
# 16          Rising Pune Supergiant
# 17                Delhi Daredevils
# 18             Sunrisers Hyderabad
# 19     Royal Challengers Bangalore
# 20             Sunrisers Hyderabad
# 21                 Kings XI Punjab
# 22           Kolkata Knight Riders
# 23                  Mumbai Indians
# 24             Sunrisers Hyderabad
# 25                 Kings XI Punjab
# 26           Kolkata Knight Riders
# ...

# %%
type(teams)
# Out:
# pandas.core.series.Series

# %%
groups = teams.groupby(teams).aggregate('count')

# %%
matches_played = pd.DataFrame(groups)
matches_played
# Out:
#                                0
# Chennai Super Kings          164
# Deccan Chargers               75
# Delhi Capitals                16
# Delhi Daredevils             161
# Gujarat Lions                 30
# Kings XI Punjab              176
# Kochi Tuskers Kerala          14
# Kolkata Knight Riders        178
# Mumbai Indians               187
# Pune Warriors                 46
# Rajasthan Royals             147
# Rising Pune Supergiant        16
# Rising Pune Supergiants       14
# Royal Challengers Bangalore  180
# Sunrisers Hyderabad          108

# %%
matches_won # dataframe
# Out:
#                              count
# winner
# Chennai Super Kings            100
# Deccan Chargers                 29
# Delhi Capitals                  10
# Delhi Daredevils                67
# Gujarat Lions                   13
# Kings XI Punjab                 82
# Kochi Tuskers Kerala             6
# Kolkata Knight Riders           92
# Mumbai Indians                 109
# Pune Warriors                   12
# Rajasthan Royals                75
# Rising Pune Supergiant          10
# Rising Pune Supergiants          5
# Royal Challengers Bangalore     84
# Sunrisers Hyderabad             58

# %%
concatenated = pd.concat([matches_played,matches_won], axis=1)
concatenated
concatenated.columns=['total', 'won']
concatenated
# Out:
#                              total  won
# winner
# Chennai Super Kings            164  100
# Deccan Chargers                 75   29
# Delhi Capitals                  16   10
# Delhi Daredevils               161   67
# Gujarat Lions                   30   13
# Kings XI Punjab                176   82
# Kochi Tuskers Kerala            14    6
# Kolkata Knight Riders          178   92
# Mumbai Indians                 187  109
# Pune Warriors                   46   12
# Rajasthan Royals               147   75
# Rising Pune Supergiant          16   10
# Rising Pune Supergiants         14    5
# Royal Challengers Bangalore    180   84
# Sunrisers Hyderabad            108   58

# %%
concatenated['lost'] = concatenated['total']- concatenated['won']
concatenated
# Out:
#                              total  won  lost
# winner
# Chennai Super Kings            164  100    64
# Deccan Chargers                 75   29    46
# Delhi Capitals                  16   10     6
# Delhi Daredevils               161   67    94
# Gujarat Lions                   30   13    17
# Kings XI Punjab                176   82    94
# Kochi Tuskers Kerala            14    6     8
# Kolkata Knight Riders          178   92    86
# Mumbai Indians                 187  109    78
# Pune Warriors                   46   12    34
# Rajasthan Royals               147   75    72
# Rising Pune Supergiant          16   10     6
# Rising Pune Supergiants         14    5     9
# Royal Challengers Bangalore    180   84    96
# Sunrisers Hyderabad            108   58    50

# %%
max_lost = concatenated['lost'].max()
max_lost
# Out:
# 96

# %%
concatenated[concatenated['lost'] == max_lost]
# Out:
#                              total  won  lost
# winner
# Royal Challengers Bangalore    180   84    96

# %% [raw]
# ANSWER -
# team that won maximum number of matches while chasing - Mumbai Indians
# team that lost maximum number of matches while chasing - Royal Challengers Bangalore
