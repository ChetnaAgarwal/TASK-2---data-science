# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [raw]
# 2. Which toss decision is best?

# %%
matches = pd.read_csv('matches.csv')
deliveries = pd.read_csv('deliveries.csv')

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
same_winner = matches[matches['toss_winner'] == matches['winner']]
diff_winner = matches[matches['toss_winner'] != matches['winner']]

# %%
favourable = same_winner.groupby('toss_decision').aggregate('count')
favourable
# Out:
#                 id  season  city  date  team1  team2  toss_winner  result  \
# toss_decision
# bat            134     134   133   134    134    134          134     134
# field          259     259   257   259    259    259          259     259
#
#                dl_applied  winner  win_by_runs  win_by_wickets  \
# toss_decision
# bat                   134     134          134             134
# field                 259     259          259             259
#
#                player_of_match  venue  umpire1  umpire2  umpire3
# toss_decision
# bat                        134    134      133      133       10
# field                      259    259      258      258       57

# %%
unfavourable = diff_winner.groupby('toss_decision').aggregate('count')
unfavourable
# Out:
#                 id  season  city  date  team1  team2  toss_winner  result  \
# toss_decision
# bat            159     159   157   159    159    159          159     159
# field          204     204   202   204    204    204          204     204
#
#                dl_applied  winner  win_by_runs  win_by_wickets  \
# toss_decision
# bat                   159     158          159             159
# field                 204     201          204             204
#
#                player_of_match  venue  umpire1  umpire2  umpire3
# toss_decision
# bat                        158    159      159      159       10
# field                      201    204      204      204       42

# %%
134-159
# Out:
# -25

# %%
259-204
# Out:
# 55

# %% [markdown]
# ANSWER - field as toss_decision is the best
