# %% [markdown]
#  Which batsman got stumped out maximum number of times?

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
deliveries = pd.read_csv('deliveries.csv')
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over   ...    bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0   ...           0
# 1     2  DA Warner    S Dhawan  TS Mills              0   ...           0
# 2     3  DA Warner    S Dhawan  TS Mills              0   ...           0
# 3     4  DA Warner    S Dhawan  TS Mills              0   ...           0
# 4     5  DA Warner    S Dhawan  TS Mills              0   ...           0
#
# ...

# %%
deliveries['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
stumped_out = deliveries[deliveries['dismissal_kind'] == 'stumped']
stumped_out
# Out:
#         match_id  inning                 batting_team  \
# 1013           5       1  Royal Challengers Bangalore
# 3024          13       2                Gujarat Lions
# 3274          14       2          Sunrisers Hyderabad
# 4006          17       2  Royal Challengers Bangalore
# 4308          18       2        Kolkata Knight Riders
# 4368          19       1          Sunrisers Hyderabad
# 4408          19       1          Sunrisers Hyderabad
# 4746          20       2                Gujarat Lions
# 6311          27       1        Kolkata Knight Riders
# 6765          29       1       Rising Pune Supergiant
# 6788          29       1       Rising Pune Supergiant
# 6791          29       1       Rising Pune Supergiant
# 7894          34       1                Gujarat Lions
# 10249         44       1               Mumbai Indians
# 10610         45       2        Kolkata Knight Riders
# 11217         48       1              Kings XI Punjab
# ...

# %%
stumped_out_count = stumped_out.groupby('batsman').aggregate('count')
max = stumped_out_count['match_id'].max()
stumped_out_count
# Out:
#                  match_id  inning  batting_team  bowling_team  over  ball  \
# batsman
# A Chopra                1       1             1             1     1     1
# A Singh                 1       1             1             1     1     1
# A Symonds               2       2             2             2     2     2
# AA Bilakhia             1       1             1             1     1     1
# AB de Villiers          6       6             6             6     6     6
# AC Gilchrist            3       3             3             3     3     3
# AD Mathews              1       1             1             1     1     1
# AG Murtaza              1       1             1             1     1     1
# AG Paunikar             1       1             1             1     1     1
# AJ Finch                3       3             3             3     3     3
# AM Rahane               4       4             4             4     4     4
# ...

# %%
max
# Out:
# 8

# %%
stumped_out_count[stumped_out_count['match_id'] == max]
# Out:
#           match_id  inning  batting_team  bowling_team  over  ball  \
# batsman
# SK Raina         8       8             8             8     8     8
#
#           non_striker  bowler  is_super_over  wide_runs  bye_runs  \
# batsman
# SK Raina            8       8              8          8         8
#
#           legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# batsman
# SK Raina            8            8             8             8           8
#
#           total_runs  player_dismissed  dismissal_kind  fielder
# batsman
# SK Raina           8                 8               8        8

# %% [raw]
# ANSWER - SK RAINA
