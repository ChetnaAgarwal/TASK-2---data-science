# %% [raw]
# Which non-striker has been part of maximum number of runouts?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
deliveries = pd.read_csv('deliveries.csv')

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over   ...    bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0   ...           0
# 1     2  DA Warner    S Dhawan  TS Mills              0   ...           0
# 2     3  DA Warner    S Dhawan  TS Mills              0   ...           0
# 3     4  DA Warner    S Dhawan  TS Mills              0   ...           0
# 4     5  DA Warner    S Dhawan  TS Mills              0   ...           0
#
# ...

# %%
deliveries['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
run_out = deliveries[deliveries['dismissal_kind'] == 'run out']
run_out
# Out:
#         match_id  inning                 batting_team  \
# 199            1       2  Royal Challengers Bangalore
# 247            1       2  Royal Challengers Bangalore
# 371            2       1               Mumbai Indians
# 1063           5       1  Royal Challengers Bangalore
# 1313           6       1                Gujarat Lions
# 1985           9       1             Delhi Daredevils
# 2700          12       1  Royal Challengers Bangalore
# 3942          17       1       Rising Pune Supergiant
# 4146          18       1             Delhi Daredevils
# 4794          20       2                Gujarat Lions
# 4989          21       2             Delhi Daredevils
# 5399          23       1        Kolkata Knight Riders
# 5546          24       1               Mumbai Indians
# 5632          24       1               Mumbai Indians
# 5635          24       1               Mumbai Indians
# 5642          24       2             Delhi Daredevils
# ...

# %%
run_out_count = run_out.groupby('non_striker').aggregate('count')
max = run_out_count['match_id'].max()
run_out_count
# Out:
#                    match_id  inning  batting_team  bowling_team  over  ball  \
# non_striker
# A Ashish Reddy            2       2             2             2     2     2
# A Chopra                  1       1             1             1     1     1
# A Choudhary               1       1             1             1     1     1
# A Kumble                  3       3             3             3     3     3
# A Mishra                  7       7             7             7     7     7
# A Nehra                   1       1             1             1     1     1
# A Nel                     1       1             1             1     1     1
# A Symonds                 6       6             6             6     6     6
# AA Chavan                 1       1             1             1     1     1
# AA Jhunjhunwala           4       4             4             4     4     4
# AB Agarkar                5       5             5             5     5     5
# ...

# %%
max
# Out:
# 16

# %%
boolean = run_out_count['match_id'] == max

# %%
boolean
# Out:
# non_striker
# A Ashish Reddy       False
# A Chopra             False
# A Choudhary          False
# A Kumble             False
# A Mishra             False
# A Nehra              False
# A Nel                False
# A Symonds            False
# AA Chavan            False
# AA Jhunjhunwala      False
# AB Agarkar           False
# AB Dinda             False
# AB de Villiers       False
# AC Gilchrist         False
# AC Voges             False
# AD Mathews           False
# AD Nath              False
# AD Russell           False
# AJ Finch             False
# AJ Tye               False
# AL Menaria           False
# AM Nayar             False
# AM Rahane            False
# AP Tare              False
# AR Patel             False
# AS Rajpoot           False
# AT Rayudu            False
# B Akhil              False
# B Chipli             False
# B Kumar              False
#                      ...
# Shahid Afridi        False
# Shakib Al Hasan      False
# Sohail Tanvir        False
# ...

# %%
run_out_count[boolean == True]
# Out:
#              match_id  inning  batting_team  bowling_team  over  ball  \
# non_striker
# KD Karthik         16      16            16            16    16    16
# SK Raina           16      16            16            16    16    16
#
#              batsman  bowler  is_super_over  wide_runs  bye_runs  legbye_runs  \
# non_striker
# KD Karthik        16      16             16         16        16           16
# SK Raina          16      16             16         16        16           16
#
#              noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# non_striker
# KD Karthik            16            16            16          16          16
# SK Raina              16            16            16          16          16
#
#              player_dismissed  dismissal_kind  fielder
# non_striker
# KD Karthik                 16              16       16
# SK Raina                   16              16       16

# %% [markdown]
# ANS - KD KARTHIK AND SK RAINA
