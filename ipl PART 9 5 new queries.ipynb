# %%
import pandas as pd
import numpy as np

# %%
deliveries = pd.read_csv('deliveries.csv')

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over   ...    bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0   ...           0
# 1     2  DA Warner    S Dhawan  TS Mills              0   ...           0
# 2     3  DA Warner    S Dhawan  TS Mills              0   ...           0
# 3     4  DA Warner    S Dhawan  TS Mills              0   ...           0
# 4     5  DA Warner    S Dhawan  TS Mills              0   ...           0
#
# ...

# %% [markdown]
# QUERY 1 - which bowler has played the minimum no of balls?

# %%
count1 = deliveries.groupby('bowler').aggregate('count')
min1 = count1['match_id'].min()
count1
# Out:
#                    match_id  inning  batting_team  bowling_team  over  ball  \
# bowler
# A Ashish Reddy          270     270           270           270   270   270
# A Chandila              234     234           234           234   234   234
# A Choudhary             108     108           108           108   108   108
# A Dananjaya              25      25            25            25    25    25
# A Flintoff               66      66            66            66    66    66
# A Joseph                 55      55            55            55    55    55
# A Kumble                983     983           983           983   983   983
# A Mishra               3172    3172          3172          3172  3172  3172
# A Mithun                312     312           312           312   312   312
# A Nehra                1974    1974          1974          1974  1974  1974
# A Nel                    18      18            18            18    18    18
# ...

# %%
min1
# Out:
# 1

# %%
bool1 = count1['match_id'] == min1
bool1
# Out:
# bowler
# A Ashish Reddy       False
# A Chandila           False
# A Choudhary          False
# A Dananjaya          False
# A Flintoff           False
# A Joseph             False
# A Kumble             False
# A Mishra             False
# A Mithun             False
# A Nehra              False
# A Nel                False
# A Roy                False
# A Singh              False
# A Symonds            False
# A Uniyal             False
# A Zampa              False
# AA Chavan            False
# AA Jhunjhunwala      False
# AA Kazi              False
# AA Noffke            False
# AB Agarkar           False
# AB Dinda             False
# AB McDonald          False
# AC Gilchrist          True
# AC Thomas            False
# AC Voges             False
# AD Mascarenhas       False
# AD Mathews           False
# AD Russell           False
# AF Milne             False
#                      ...
# TL Suman             False
# TM Dilshan           False
# TM Head              False
# ...

# %%
count1[bool1 == True]
# Out:
#               match_id  inning  batting_team  bowling_team  over  ball  \
# bowler
# AC Gilchrist         1       1             1             1     1     1
#
#               batsman  non_striker  is_super_over  wide_runs  bye_runs  \
# bowler
# AC Gilchrist        1            1              1          1         1
#
#               legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# bowler
# AC Gilchrist            1            1             1             1
#
#               extra_runs  total_runs  player_dismissed  dismissal_kind  \
# bowler
# AC Gilchrist           1           1                 1               1
#
#               fielder
# bowler
# AC Gilchrist        1

# %% [markdown]
# ANSWER 1 - AC GILCHRIST

# %% [markdown]
# QUERY 2 - which team has batted maximum no of times in the first inning?

# %%
first_inning = deliveries[deliveries['inning'] == 1]
count2 = first_inning.groupby('batting_team').aggregate('count')
max2 = count2['match_id'].max()
count2
# Out:
#                              match_id  inning  bowling_team   over   ball  \
# batting_team
# Chennai Super Kings             10974   10974         10974  10974  10974
# Deccan Chargers                  5280    5280          5280   5280   5280
# Delhi Capitals                    739     739           739    739    739
# Delhi Daredevils                 8753    8753          8753   8753   8753
# Gujarat Lions                    1726    1726          1726   1726   1726
# Kings XI Punjab                 11119   11119         11119  11119  11119
# Kochi Tuskers Kerala              876     876           876    876    876
# Kolkata Knight Riders           10112   10112         10112  10112  10112
# Mumbai Indians                  12578   12578         12578  12578  12578
# Pune Warriors                    2448    2448          2448   2448   2448
# Rajasthan Royals                 8235    8235          8235   8235   8235
# ...

# %%
bool2 = count2['match_id'] == max2

# %%
count2[bool2 == True]
# Out:
#                 match_id  inning  bowling_team   over   ball  batsman  \
# batting_team
# Mumbai Indians     12578   12578         12578  12578  12578    12578
#
#                 non_striker  bowler  is_super_over  wide_runs  bye_runs  \
# batting_team
# Mumbai Indians        12578   12578          12578      12578     12578
#
#                 legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# batting_team
# Mumbai Indians        12578        12578         12578         12578
#
#                 extra_runs  total_runs  player_dismissed  dismissal_kind  \
# batting_team
# Mumbai Indians       12578       12578               616             616
#
#                 fielder
# batting_team
# Mumbai Indians      459

# %% [markdown]
# ANSWER 2 - MUMBAI INDIANS

# %% [markdown]
# QUERY 3 - Which is the most popular toss decision?

# %%
matches = pd.read_csv('matches.csv')

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
toss_groups = matches.groupby('toss_decision').aggregate('count')
toss_groups
# Out:
#                 id  season  city  date  team1  team2  toss_winner  result  \
# toss_decision
# bat            293     293   290   293    293    293          293     293
# field          463     463   459   463    463    463          463     463
#
#                dl_applied  winner  win_by_runs  win_by_wickets  \
# toss_decision
# bat                   293     292          293             293
# field                 463     460          463             463
#
#                player_of_match  venue  umpire1  umpire2  umpire3
# toss_decision
# bat                        292    293      292      292       20
# field                      460    463      462      462       99

# %% [markdown]
# ANSWER 3 - FIELD

# %% [markdown]
# QUERY 4 - In which season were maximum number of games played?

# %%
s = matches.groupby('season').aggregate('count')
s
# Out:
#         id  city  date  team1  team2  toss_winner  toss_decision  result  \
# season
# 2008    58    58    58     58     58           58             58      58
# 2009    57    57    57     57     57           57             57      57
# 2010    60    60    60     60     60           60             60      60
# 2011    73    73    73     73     73           73             73      73
# 2012    74    74    74     74     74           74             74      74
# 2013    76    76    76     76     76           76             76      76
# 2014    60    53    60     60     60           60             60      60
# 2015    59    59    59     59     59           59             59      59
# 2016    60    60    60     60     60           60             60      60
# 2017    59    59    59     59     59           59             59      59
# 2018    60    60    60     60     60           60             60      60
# 2019    60    60    60     60     60           60             60      60
#
# ...

# %% [markdown]
# ANSWER 4 - 2013

# %% [markdown]
# QUERY 5 - Which is the most popular venue?

# %%
ven_count = matches.groupby('venue').aggregate('count')
ven_count
# Out:
#                                                     id  season  city  date  \
# venue
# ACA-VDCA Stadium                                     2       2     2     2
# Barabati Stadium                                     7       7     7     7
# Brabourne Stadium                                   11      11    11    11
# Buffalo Park                                         3       3     3     3
# De Beers Diamond Oval                                3       3     3     3
# Dr DY Patil Sports Academy                          17      17    17    17
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...  11      11    11    11
# Dubai International Cricket Stadium                  7       7     0     7
# Eden Gardens                                        77      77    77    77
# Feroz Shah Kotla                                    67      67    67    67
# Feroz Shah Kotla Ground                              7       7     7     7
# ...

# %%
max = ven_count['id'].max()
max
# Out:
# 77

# %%
ven_count[ven_count['id'] == max]
# Out:
#               id  season  city  date  team1  team2  toss_winner  \
# venue
# Eden Gardens  77      77    77    77     77     77           77
#
#               toss_decision  result  dl_applied  winner  win_by_runs  \
# venue
# Eden Gardens             77      77          77      77           77
#
#               win_by_wickets  player_of_match  umpire1  umpire2  umpire3
# venue
# Eden Gardens              77               77       77       77       16

# %% [markdown]
# ANSWER 5 - EDEN GARDENS
